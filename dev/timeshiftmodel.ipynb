# %%
import pandas as pd
import numpy as np
import os

df = pd.read_csv(os.path.join(os.path.join("data", "flight_data_processed.csv")))
df["nextClimbRate"] = df["climb_rate_m/s"].shift(-5)
df.fillna(0, inplace=True)
df.head(10)
# Out:
# /var/folders/ss/5qhyykzn7ws047pz5bmmgw1r0000gn/T/ipykernel_31485/1856521376.py:5: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(os.path.join("data", "flight_data_processed.csv")))
#            filename             datetime pilot   latitude  longitude  \
# 0  serdar rekor.igc  2021-07-22 08:30:13     0  40.031217  32.328283
# 1  serdar rekor.igc  2021-07-22 08:30:14     0  40.031217  32.328200
# 2  serdar rekor.igc  2021-07-22 08:30:15     0  40.031217  32.328133
# 3  serdar rekor.igc  2021-07-22 08:30:16     0  40.031217  32.328050
# 4  serdar rekor.igc  2021-07-22 08:30:17     0  40.031233  32.327983
# 5  serdar rekor.igc  2021-07-22 08:30:18     0  40.031250  32.327917
# 6  serdar rekor.igc  2021-07-22 08:30:19     0  40.031267  32.327850
# 7  serdar rekor.igc  2021-07-22 08:30:20     0  40.031267  32.327767
# 8  serdar rekor.igc  2021-07-22 08:30:21     0  40.031283  32.327683
# ...

# %%
df.to_csv(os.path.join(os.path.join("data", "flight_data_processed2.csv")), index=False)
